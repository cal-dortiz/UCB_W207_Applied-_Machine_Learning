# %% [markdown]
# # Transformation Study

# %%
# Import Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data_url = 'https://raw.githubusercontent.com/cal-dortiz/W207_Applied-_Machine_Learning/main/Final_Project/Data/train.csv'
df_train = pd.read_csv(train_data_url)

df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Same plot with Seaborn 
sns.distplot(np.log(df_train['SalePrice']))

# %% [markdown]
# ## MSSubClass

# %%
sns.distplot(df_train['MSSubClass'])
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSSubClass', ylabel='Density'>

# %%
sns.distplot(np.log(df_train['MSSubClass']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSSubClass', ylabel='Density'>

# %% [markdown]
# ## LotFrontage

# %%
sns.distplot(df_train['LotFrontage'])
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotFrontage', ylabel='Density'>

# %%
sns.distplot(np.log(df_train['LotFrontage']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotFrontage', ylabel='Density'>

# %% [markdown]
# ## LotArea

# %% [markdown]
# Conclusion: LotArea should be log Transformed

# %%
sns.distplot(df_train['LotArea'])
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %%
sns.distplot(np.log(df_train['LotArea']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %% [markdown]
# ## OverallQual

# %% [markdown]
# Conclusion: OverallQual should be treated as an ordinal variavble

# %%
sns.distplot(df_train['OverallQual'])
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='OverallQual', ylabel='Density'>

# %%
sns.distplot(np.log(df_train['OverallQual']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='OverallQual', ylabel='Density'>

# %% [markdown]
# ## OverallCond

# %% [markdown]
# Conclusion: OverallQual should be treated as an ordinal variavble

# %%
sns.distplot(df_train['OverallCond'])
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='OverallCond', ylabel='Density'>

# %%
sns.distplot(np.log(df_train['OverallCond']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='OverallCond', ylabel='Density'>

# %% [markdown]
# ## YearBuilt

# %%
sns.distplot(df_train['YearBuilt'])
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearBuilt', ylabel='Density'>

# %%
sns.distplot(np.log(df_train['YearBuilt']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearBuilt', ylabel='Density'>

# %% [markdown]
# ## YearRemodAdd

# %%
sns.distplot(df_train['YearRemodAdd'])
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='Density'>

# %%
sns.distplot(np.log(df_train['YearRemodAdd']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='Density'>

# %% [markdown]
# ## MasVnrArea

# %%
sns.distplot(df_train['MasVnrArea'])
# Out:
# <AxesSubplot:xlabel='MasVnrArea', ylabel='Density'>

# %%
mva = df_train[['MasVnrArea']].copy()

mva = mva.dropna()
mva

sns.distplot(np.log(mva['MasVnrArea']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2397: RuntimeWarning: invalid value encountered in double_scalars
#   return int(np.ceil((a.max() - a.min()) / h))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-b0ac50d8a895> in <module>
#       4 mva
# ...

# %% [markdown]
# ## BsmtFinSF1

# %%
sns.distplot(df_train['BsmtFinSF1'])
# Out:
# <AxesSubplot:xlabel='BsmtFinSF1', ylabel='Density'>

# %%
bmt = df_train[['BsmtFinSF1']].copy()

bmt = bmt.dropna()
sns.distplot(np.log(bmt['BsmtFinSF1']))
# Out:
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/danielortiz/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2397: RuntimeWarning: invalid value encountered in double_scalars
#   return int(np.ceil((a.max() - a.min()) / h))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-b2f034dce0d7> in <module>
#       4 mva
# ...

# %% [markdown]
# ## BstFinSF2

# %% [markdown]
# ## BstUnfSF

# %% [markdown]
# ## TotalBsmtSF

# %% [markdown]
# ## 1stFlrSF

# %% [markdown]
# ## 2ndFlrSF

# %% [markdown]
# ## LowQualFinSF
